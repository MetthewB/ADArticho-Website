# %% [markdown]
# Les datas sont dans le drive

# %%
import matplotlib.colors as mcolors

topic_colors = {
    'Love': mcolors.CSS4_COLORS['red'],
    'Family': mcolors.CSS4_COLORS['deeppink'],
    'School': mcolors.CSS4_COLORS['dodgerblue'],
    'Work': mcolors.CSS4_COLORS['steelblue'],
    'Politics and Social Issues': mcolors.CSS4_COLORS['palevioletred'],
    'Nature': mcolors.CSS4_COLORS['darkgreen'],
    'Food': mcolors.CSS4_COLORS['darkorange'],
    'Emotions': mcolors.CSS4_COLORS['lightseagreen'],
    'Entertainment and Pop Culture': mcolors.CSS4_COLORS['mediumorchid'],
    'Caption contest': mcolors.CSS4_COLORS['blue'],
    "Health": mcolors.CSS4_COLORS['teal'],
    'Law': mcolors.CSS4_COLORS['blueviolet'],
    'Other': mcolors.CSS4_COLORS['dimgrey']
}

topic_order = [key for key,v in topic_colors.items()]

# %%
from src.data.load_data import load_classified_dataset

# Reload classified datasets and set lowest matched 75 percentile as 'Other'
newyorker_classified = load_classified_dataset('results_topics/newyorker_topics.csv',low_quantile=0.75, dates_col= True)
oxford_classified = load_classified_dataset('results_topics/oxford_topics.csv',low_quantile=0.75, dates_col= False)

# %%
import importlib
from src.utils import plots
importlib.reload(plots)

from src.utils.plots import app_caption_time_prop
from src.utils.plots import topic_distribution_piechart_plotly, plotly_topic_variation_heatmap

from plotly.io import write_html

fig1 = topic_distribution_piechart_plotly(newyorker_classified[newyorker_classified['Topic'] != 'Other'], oxford_classified[oxford_classified['Topic'] != 'Other'], 'New Yorker', 'Oxford', topic_order[:-1], topic_colors)
write_html(fig1, "topic_distribution_piechart.html")

app = app_caption_time_prop(newyorker_classified, topic_order, topic_colors)
app.run(debug=True, port=8060)

fig2 = plotly_topic_variation_heatmap(newyorker_classified, topic_order)
write_html(fig2, "topic_variation_heatmap.html")
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8060/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
